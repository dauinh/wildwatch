# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('./data/EN.csv')
df.head()
# Out:
#           id            conservation_actions  \
# 0  253647117                              []
# 1  253647972                              []
# 2  253648235                              []
# 3  254095929  ['3_3_1', '1_1', '4_3', '2_1']
# 4  254178918           ['2_2', '1_1', '1_2']
#
#                                             habitats  \
# 0         [('1_5', None, None), ('1_6', None, None)]
# 1         [('1_6', None, None), ('1_9', None, None)]
# 2                              [('1_5', None, None)]
# 3  [('1_5', 'Yes', 'Resident'), ('1_6', 'Yes', 'R...
# 4                       [('5_1', 'Yes', 'Resident')]
#
#                                            locations  population_trend  \
# 0                  [('Native', 'PR', 'Puerto Rico')]                 3
# 1                  [('Native', 'PR', 'Puerto Rico')]                 3
# 2                  [('Native', 'PR', 'Puerto Rico')]                 3
# 3  [('Native', 'IND-MR', 'Maharashtra'), ('Native...                 1
# 4           [('Native', 'KR', 'Korea, Republic of')]                 2
#
#    possibly_extinct  possibly_extinct_in_the_wild  sis_taxon_id  \
# 0             False                         False     212060056
# 1             False                         False         35635
# 2             False                         False         30969
# 3             False                         False     254095810
# 4             False                         False     148447462
#
#   estimated_area_of_occupancy estimated_extent_of_occurence     taxon  \
# 0                         NaN                            55   PLANTAE
# 1                         NaN                            67   PLANTAE
# 2                         NaN                           326   PLANTAE
# 3                          68                          5315   PLANTAE
# 4                          32                            32  ANIMALIA
#
#                                              threats  \
# 0  [('7_1_1', 'Ongoing', None, 'Low Impact: 3', N...
# 1  [('11_4', 'Ongoing', None, 'Low Impact: 3', No...
# 2  [('1_1', 'Ongoing', None, 'Low Impact: 3', Non...
# 3  [('2_1_2', 'Ongoing', 'Minority (<50%)', 'Low ...
# 4  [('8_1_2', 'Past, Likely to Return', 'Majority...
#
#                                                  url
# 0  https://www.iucnredlist.org/species/212060056/...
# 1  https://www.iucnredlist.org/species/35635/2536...
# 2  https://www.iucnredlist.org/species/30969/2536...
# 3  https://www.iucnredlist.org/species/254095810/...
# 4  https://www.iucnredlist.org/species/148447462/...

# %%
def create_relationship_table(table, column, is_tuple=False, tuples=[]):
    table = df[['id', column]].copy()
    table[column] = table[column].apply(ast.literal_eval)
    table = table.explode(column).dropna().reset_index(drop=True)
    if is_tuple:
        table[tuples] = pd.DataFrame(table[column].tolist(), index=table.index)
    return table

# %%
en_conservation_actions_df = create_relationship_table('en_conservation_actions_df', 'conservation_actions')
en_conservation_actions_df['group'] = en_conservation_actions_df['conservation_actions'].apply(lambda x: x[0])
en_conservation_actions_df.head()
# Out:
#           id conservation_actions group
# 0  254095929                3_3_1     3
# 1  254095929                  1_1     1
# 2  254095929                  4_3     4
# 3  254095929                  2_1     2
# 4  254178918                  2_2     2

# %%
en_habitats_df = create_relationship_table('en_habitats_df', 'habitats', is_tuple=True, tuples=['code', 'majorImportance', 'season']).drop('habitats', axis=1)
en_habitats_df['group'] = en_habitats_df['code'].apply(lambda x: x[0])
en_habitats_df.head()
# Out:
#           id code majorImportance season group
# 0  253647117  1_5            None   None     1
# 1  253647117  1_6            None   None     1
# 2  253647972  1_6            None   None     1
# 3  253647972  1_9            None   None     1
# 4  253648235  1_5            None   None     1

# %%
en_locations_df = create_relationship_table('en_locations_df', 'locations', is_tuple=True, tuples=['origin', 'code', 'description']).drop('locations', axis=1)
en_locations_df.head()
# Out:
#           id  origin    code  description
# 0  253647117  Native      PR  Puerto Rico
# 1  253647972  Native      PR  Puerto Rico
# 2  253648235  Native      PR  Puerto Rico
# 3  254095929  Native  IND-MR  Maharashtra
# 4  254095929  Native      IN        India

# %%
en_threats_df = create_relationship_table('en_threats_df', 'threats', is_tuple=True, tuples=['code', 'timing', 'scope', 'score', 'severity']).drop('threats', axis=1)
en_threats_df['group'] = en_threats_df['code'].apply(lambda x: x[0])
en_threats_df.head()
# Out:
#           id   code   timing scope          score severity group
# 0  253647117  7_1_1  Ongoing  None  Low Impact: 3     None     7
# 1  253647117   10_3  Ongoing  None  Low Impact: 3     None     1
# 2  253647117   11_4  Ongoing  None  Low Impact: 3     None     1
# 3  253647117    1_1  Ongoing  None  Low Impact: 3     None     1
# 4  253647117    4_2  Ongoing  None  Low Impact: 3     None     4

# %%
en_main_df = df.drop(['conservation_actions', 'locations', 'habitats', 'threats'], axis=1)
en_main_df.head()
# Out:
#           id  population_trend  possibly_extinct  \
# 0  253647117                 3             False
# 1  253647972                 3             False
# 2  253648235                 3             False
# 3  254095929                 1             False
# 4  254178918                 2             False
#
#    possibly_extinct_in_the_wild  sis_taxon_id estimated_area_of_occupancy  \
# 0                         False     212060056                         NaN
# 1                         False         35635                         NaN
# 2                         False         30969                         NaN
# 3                         False     254095810                          68
# 4                         False     148447462                          32
#
#   estimated_extent_of_occurence     taxon  \
# 0                            55   PLANTAE
# 1                            67   PLANTAE
# 2                           326   PLANTAE
# 3                          5315   PLANTAE
# 4                            32  ANIMALIA
#
#                                                  url
# 0  https://www.iucnredlist.org/species/212060056/...
# 1  https://www.iucnredlist.org/species/35635/2536...
# 2  https://www.iucnredlist.org/species/30969/2536...
# 3  https://www.iucnredlist.org/species/254095810/...
# 4  https://www.iucnredlist.org/species/148447462/...

# %%
en_main_df.to_csv('./data/en_main.csv', header=True, index=False)
en_habitats_df.to_csv('./data/en_habitats.csv', header=True, index=False)
en_locations_df.to_csv('./data/en_locations.csv', header=True, index=False)
en_conservation_actions_df.to_csv('./data/en_conservation_actions.csv', header=True, index=False)
en_threats_df.to_csv('./data/en_threats.csv', header=True, index=False)
