# %%
import pandas as pd
import numpy as np
import ast

# %%
df = pd.read_csv('./data/EN.csv')
df.head()
# Out:
#           id            conservation_actions  \
# 0  253647117                              []
# 1  253647972                              []
# 2  253648235                              []
# 3  254095929  ['3_3_1', '1_1', '4_3', '2_1']
# 4  254178918           ['2_2', '1_1', '1_2']
#
#                                             habitats  \
# 0         [('1_5', None, None), ('1_6', None, None)]
# 1         [('1_6', None, None), ('1_9', None, None)]
# 2                              [('1_5', None, None)]
# 3  [('1_5', 'Yes', 'Resident'), ('1_6', 'Yes', 'R...
# 4                       [('5_1', 'Yes', 'Resident')]
#
#                                   locations  population_trend  \
# 0                        [('Native', 'PR')]                 3
# 1                        [('Native', 'PR')]                 3
# 2                        [('Native', 'PR')]                 3
# 3  [('Native', 'IND-MR'), ('Native', 'IN')]                 1
# 4                        [('Native', 'KR')]                 2
#
#    possibly_extinct  possibly_extinct_in_the_wild  sis_taxon_id  \
# 0             False                         False     212060056
# 1             False                         False         35635
# 2             False                         False         30969
# 3             False                         False     254095810
# 4             False                         False     148447462
#
#   estimated_area_of_occupancy estimated_extent_of_occurence     taxon  \
# 0                         NaN                            55   PLANTAE
# 1                         NaN                            67   PLANTAE
# 2                         NaN                           326   PLANTAE
# 3                          68                          5315   PLANTAE
# 4                          32                            32  ANIMALIA
#
#                                              threats  \
# 0  [('7_1_1', 'Ongoing', None, 'Low Impact: 3', N...
# 1  [('11_4', 'Ongoing', None, 'Low Impact: 3', No...
# 2  [('1_1', 'Ongoing', None, 'Low Impact: 3', Non...
# 3  [('2_1_2', 'Ongoing', 'Minority (<50%)', 'Low ...
# 4  [('8_1_2', 'Past, Likely to Return', 'Majority...
#
#                                                  url
# 0  https://www.iucnredlist.org/species/212060056/...
# 1  https://www.iucnredlist.org/species/35635/2536...
# 2  https://www.iucnredlist.org/species/30969/2536...
# 3  https://www.iucnredlist.org/species/254095810/...
# 4  https://www.iucnredlist.org/species/148447462/...

# %%
def create_relationship_table(table, column, is_tuple=False, tuples=[]):
    table = df[['id', column]].copy()
    table[column] = table[column].apply(ast.literal_eval)
    table = table.explode(column).dropna().reset_index(drop=True)
    if is_tuple:
        table[tuples] = pd.DataFrame(table[column].tolist(), index=table.index)
    return table

# %%
habitats_df = create_relationship_table('habitats_df', 'habitats', is_tuple=True, tuples=['code', 'majorImportance', 'season']).drop('habitats', axis=1)
habitats_df.head()
# Out:
#           id code majorImportance season
# 0  253647117  1_5            None   None
# 1  253647117  1_6            None   None
# 2  253647972  1_6            None   None
# 3  253647972  1_9            None   None
# 4  253648235  1_5            None   None

# %%
conser_act_df = create_relationship_table('conser_act_df', 'conservation_actions')
conser_act_df.head()
# Out:
#           id conservation_actions
# 0  254095929                3_3_1
# 1  254095929                  1_1
# 2  254095929                  4_3
# 3  254095929                  2_1
# 4  254178918                  2_2
